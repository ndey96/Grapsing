# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ls Data/
# Out:
# flipped_neg_data_in_camera_coordinates.csv
# matched_neg_data_in_camera_coordinates.csv*
# matched_pos_data_in_camera_coordinates.csv*
# prior_compact.npy*
# prior_pos.npy*
# training_image_data.npy*
# training_uids.npy*
# uids.npy*
# validation_image_data.npy*
# validation_uids.npy*

# %%
val_imgs = np.load('Data/validation_image_data.npy')
val_imgs.shape
# Out:
# (1000, 224, 224, 3)

# %%
depth_val_imgs = val_imgs[:,:,:,2]

# %%
plt.imshow(depth_val_imgs[0])

# %%
depth_val_imgs.shape
# Out:
# (1000, 224, 224)

# %%
np.save('Data/depth_validation_image_data.npy', depth_val_imgs)

# %%
plt.imshow(np.load('Data/depth_validation_image_data.npy')[0])

# %%
np.save('Data/depth_training_image_data.npy', np.load('Data/training_image_data.npy')[:,:,:,2])
